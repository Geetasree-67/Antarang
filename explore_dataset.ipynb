# %%
import pandas as pd
df=pd.read_csv('disposal-time-index-2026-data.csv')
df.info()
df.head()
df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3296 entries, 0 to 3295
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   cnr               3296 non-null   object
#  1   courtCode         3296 non-null   object
#  2   courtName         3271 non-null   object
#  3   stateCode         3296 non-null   object
#  4   stateName         3296 non-null   object
#  5   caseType          3296 non-null   object
#  6   filingDate        3296 non-null   object
#  7   decisionDate      3296 non-null   object
#  8   caseDurationDays  3296 non-null   int64
#  9   cohort            3296 non-null   object
#  10  filingYear        3296 non-null   int64
#  11  decisionYear      3296 non-null   int64
#  12  hasJudgments      3296 non-null   bool
#  13  tier              3296 non-null   object
# dtypes: bool(1), int64(3), object(10)
# memory usage: 338.1+ KB
# (3296, 14)
